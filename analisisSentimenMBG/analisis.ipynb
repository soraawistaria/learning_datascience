# %%
import numpy as np 
import pandas as pd 

df = pd.read_json("mbg_tiktokcomment.json")
df.head()
# Out:
#               video_id           comment_id    parent_comment_id level  \
# 0  7553950099299110151  7554042072476943111                          0
# 1  7553950099299110151  7554050261040661266  7554042072476943111     1
# 2  7553950099299110151  7554184392182055687  7554042072476943111     1
# 3  7553950099299110151  7554145436236776208  7554042072476943111     1
# 4  7553950099299110151  7554951123045516049  7554042072476943111     1
#
#             username              nickname  \
# 0           aris.jo2               Aris Jo
# 1  heztyannadrwskinc  Hezty Anna DrwSkinca
# 2           royantek             Roy Ahmad
# 3            bitas__               bitas__
# 4         shiva.slv_         ⋆𐙚｡Shiva.ᡣ𐭩˚˚
#
#                                              comment         create_time  \
# 0  ibuk ngomongnya, TIMES NEW ROMAN, BOLD, CAPLOC... 2025-09-25 22:01:26
# 1             ENTER ENTER ENTER Langsung ke INTI nya 2025-09-25 22:33:09
# ...

# %%
df.info()

# %%
df.shape
df.isnull().sum()
# Out:
# video_id             0
# comment_id           0
# parent_comment_id    0
# level                0
# username             0
# nickname             0
# comment              0
# create_time          0
# avatar               0
# total_reply          0
# replies              0
# dtype: int64
