# %% [markdown]
# Read dataset

# %%
import pandas as pd 

df = pd.read_csv('cafe_scrap.csv')

df
# Out:
#                                   input_id  \
# 0     3043499d-f7a0-4139-b121-07920cff8870
# 1     3043499d-f7a0-4139-b121-07920cff8870
# 2     3043499d-f7a0-4139-b121-07920cff8870
# 3     3043499d-f7a0-4139-b121-07920cff8870
# 4     3043499d-f7a0-4139-b121-07920cff8870
# ...                                    ...
# 1247  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1248  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1249  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1250  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1251  7b7b74fe-1364-4bd8-94a8-bf8df1501912
#
#                                                    link  \
# 0     https://www.google.com/maps/place/Kise+Coffee/...
# 1     https://www.google.com/maps/place/Berdua+Coffe...
# 2     https://www.google.com/maps/place/Caffeinated/...
# 3     https://www.google.com/maps/place/DE+VILLAGE+C...
# 4     https://www.google.com/maps/place/All-Co+Veter...
# ...                                                 ...
# ...

# %%
pd.set_option('display.max_info_columns', 50)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   input_id               1252 non-null   str
#  1   link                   1252 non-null   str
#  2   title                  1252 non-null   str
#  3   category               1250 non-null   str
#  4   address                1252 non-null   str
#  5   open_hours             1252 non-null   str
#  6   popular_times          1252 non-null   str
#  7   website                228 non-null    str
#  8   phone                  705 non-null    str
#  9   plus_code              736 non-null    str
#  10  review_count           1252 non-null   int64
#  11  review_rating          1252 non-null   float64
#  12  reviews_per_rating     1252 non-null   str
#  13  latitude               1252 non-null   float64
#  14  longitude              1252 non-null   float64
# ...

# %%
for i, col in enumerate(df.columns):
    print(f"{i}: {col}")
# Out:
# 0: input_id
# 1: link
# 2: title
# 3: category
# 4: address
# 5: open_hours
# 6: popular_times
# 7: website
# 8: phone
# 9: plus_code
# 10: review_count
# 11: review_rating
# 12: reviews_per_rating
# 13: latitude
# 14: longitude
# 15: cid
# 16: status
# 17: descriptions
# 18: reviews_link
# 19: thumbnail
# 20: timezone
# 21: price_range
# 22: data_id
# 23: street_view_url
# 24: place_id
# 25: images
# 26: reservations
# 27: order_online
# 28: menu
# 29: owner
# 30: complete_address
# 31: credit_cards_accepted
# 32: about
# 33: user_reviews
# 34: user_reviews_extended
# 35: emails

# %%
df = df.drop(columns=['reviews_link', 'user_reviews_extended', 'emails', 'user_reviews', 'thumbnail', 'street_view_url'])

for i, col in enumerate(df.columns):
    print(f"{i}: {col}")
# Out:
# 0: input_id
# 1: link
# 2: title
# 3: category
# 4: address
# 5: open_hours
# 6: popular_times
# 7: website
# 8: phone
# 9: plus_code
# 10: review_count
# 11: review_rating
# 12: reviews_per_rating
# 13: latitude
# 14: longitude
# 15: cid
# 16: status
# 17: descriptions
# 18: timezone
# 19: price_range
# 20: data_id
# 21: place_id
# 22: images
# 23: reservations
# 24: order_online
# 25: menu
# 26: owner
# 27: complete_address
# 28: credit_cards_accepted
# 29: about

# %%
df = df.drop_duplicates()

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   input_id               1252 non-null   str
#  1   link                   1252 non-null   str
#  2   title                  1252 non-null   str
#  3   category               1250 non-null   str
#  4   address                1252 non-null   str
#  5   open_hours             1252 non-null   str
#  6   popular_times          1252 non-null   str
#  7   website                228 non-null    str
#  8   phone                  705 non-null    str
#  9   plus_code              736 non-null    str
#  10  review_count           1252 non-null   int64
#  11  review_rating          1252 non-null   float64
#  12  reviews_per_rating     1252 non-null   str
#  13  latitude               1252 non-null   float64
#  14  longitude              1252 non-null   float64
# ...

# %%
df = df.drop(columns=['descriptions', 'status', 'price_range', 'credit_cards_accepted', 'about'])

df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = df.drop(columns=['descriptions', 'status', 'price_range', 'credit_cards_accepted', 'about', 'phone', 'plus_code', 'website'])
#       3 df.info()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
# ...

# %%
df = df.drop(columns=['phone', 'plus_code', 'website'])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_id            1252 non-null   str
#  1   link                1252 non-null   str
#  2   title               1252 non-null   str
#  3   category            1250 non-null   str
#  4   address             1252 non-null   str
#  5   open_hours          1252 non-null   str
#  6   popular_times       1252 non-null   str
#  7   review_count        1252 non-null   int64
#  8   review_rating       1252 non-null   float64
#  9   reviews_per_rating  1252 non-null   str
#  10  latitude            1252 non-null   float64
#  11  longitude           1252 non-null   float64
#  12  cid                 1252 non-null   uint64
#  13  timezone            1252 non-null   str
#  14  data_id             1252 non-null   str
#  15  place_id            1252 non-null   str
# ...

# %%
df = df.drop(columns=['timezone', 'reservations', 'order_online', 'complete_address', 'owner', 'order_online'])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_id            1252 non-null   str
#  1   link                1252 non-null   str
#  2   title               1252 non-null   str
#  3   category            1250 non-null   str
#  4   address             1252 non-null   str
#  5   open_hours          1252 non-null   str
#  6   popular_times       1252 non-null   str
#  7   review_count        1252 non-null   int64
#  8   review_rating       1252 non-null   float64
#  9   reviews_per_rating  1252 non-null   str
#  10  latitude            1252 non-null   float64
#  11  longitude           1252 non-null   float64
#  12  cid                 1252 non-null   uint64
#  13  data_id             1252 non-null   str
#  14  place_id            1252 non-null   str
#  15  images              1252 non-null   str
# ...

# %%
df = df.dropna(subset=['category'])

df = df.drop_duplicates(subset=['place_id'])

df = df.drop_duplicates(subset=['cid'])

df = df.drop_duplicates(subset=['data_id'])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1250 entries, 0 to 1251
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_id            1250 non-null   str
#  1   link                1250 non-null   str
#  2   title               1250 non-null   str
#  3   category            1250 non-null   str
#  4   address             1250 non-null   str
#  5   open_hours          1250 non-null   str
#  6   popular_times       1250 non-null   str
#  7   review_count        1250 non-null   int64
#  8   review_rating       1250 non-null   float64
#  9   reviews_per_rating  1250 non-null   str
#  10  latitude            1250 non-null   float64
#  11  longitude           1250 non-null   float64
#  12  cid                 1250 non-null   uint64
#  13  data_id             1250 non-null   str
#  14  place_id            1250 non-null   str
#  15  images              1250 non-null   str
# ...

# %%
print(df['category'].unique())
# Out:
# <StringArray>
# [                 'Coffee shop',                         'Cafe',
#                    'Juice shop',                   'Donut shop',
#                     'Cake shop',               'Ice cream shop',
#  'Food and beverage consultant',                   'Restaurant',
#                  'Espresso bar',                 'Coffee store',
#                        'Bakery',                 'Coffee stand',
#               'Coffee roastery',                     'Art cafe',
#                           'Bar',                 'Dessert shop',
#                    'Night club',            'Buffet restaurant',
#             'Seblak restaurant',                 'Soup kitchen',
#            'Chicken restaurant',                'Internet cafe',
#             'Brunch restaurant',                    'Rest stop',
#                      'Car wash',                        'Diner',
#                     'Snack bar',                'General store',
# ...

# %%
df[df['category'] == 'Night club']
# Out:
#                                   input_id  \
# 467   e399366b-ca17-4837-aaa6-8384ff2b8ed1
# 1001  b6820552-2113-494b-9a3c-621f13137e91
# 1008  b6820552-2113-494b-9a3c-621f13137e91
#
#                                                    link            title  \
# 467   https://www.google.com/maps/place/Cafe+ternak/...      Cafe ternak
# 1001  https://www.google.com/maps/place/Cafe+99+Kara...  Cafe 99 Karaoke
# 1008  https://www.google.com/maps/place/cafe+angel/d...       cafe angel
#
#         category                                            address  \
# 467   Night club  JFCF+847 Cafe ternak, Mampari, Kec. Batu Mandi...
# 1001  Night club  RCFF+7H7 Cafe 99 Karaoke, Jl. Mabuun Raya, Mab...
# 1008  Night club  VF83+93G cafe angel, Dekat, Jl. Tj. - Kuaro, K...
#
#                                              open_hours  \
# 467   {"Friday":["Open 24 hours"],"Monday":["Open 24...
# 1001                                                 {}
# ...

# %%
kategori_dihapus = ['Night club', 'Car wash', 'Clothing store', 'Karaoke bar', 'Health consultant', 'Bar']

# Simpan baris yang kategorinya BUKAN bagian dari daftar di atas
df = df[~df['category'].isin(kategori_dihapus)]
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1237 entries, 0 to 1251
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_id            1237 non-null   str
#  1   link                1237 non-null   str
#  2   title               1237 non-null   str
#  3   category            1237 non-null   str
#  4   address             1237 non-null   str
#  5   open_hours          1237 non-null   str
#  6   popular_times       1237 non-null   str
#  7   review_count        1237 non-null   int64
#  8   review_rating       1237 non-null   float64
#  9   reviews_per_rating  1237 non-null   str
#  10  latitude            1237 non-null   float64
#  11  longitude           1237 non-null   float64
#  12  cid                 1237 non-null   uint64
#  13  data_id             1237 non-null   str
#  14  place_id            1237 non-null   str
#  15  images              1237 non-null   str
# ...

# %%
# Simpan DataFrame ke file CSV
# index=False digunakan agar nomor baris pandas tidak ikut tersimpan sebagai kolom baru
df.to_csv('clean_data_cafekalsel.csv', index=False, encoding='utf-8')
