# %% [markdown]
# Read dataset

# %%
import pandas as pd 

df = pd.read_csv('cafe_scrap.csv')

df
# Out:
#                                   input_id  \
# 0     3043499d-f7a0-4139-b121-07920cff8870
# 1     3043499d-f7a0-4139-b121-07920cff8870
# 2     3043499d-f7a0-4139-b121-07920cff8870
# 3     3043499d-f7a0-4139-b121-07920cff8870
# 4     3043499d-f7a0-4139-b121-07920cff8870
# ...                                    ...
# 1247  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1248  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1249  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1250  7b7b74fe-1364-4bd8-94a8-bf8df1501912
# 1251  7b7b74fe-1364-4bd8-94a8-bf8df1501912
#
#                                                    link  \
# 0     https://www.google.com/maps/place/Kise+Coffee/...
# 1     https://www.google.com/maps/place/Berdua+Coffe...
# 2     https://www.google.com/maps/place/Caffeinated/...
# 3     https://www.google.com/maps/place/DE+VILLAGE+C...
# 4     https://www.google.com/maps/place/All-Co+Veter...
# ...                                                 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   input_id               1252 non-null   str
#  1   link                   1252 non-null   str
#  2   title                  1252 non-null   str
#  3   category               1250 non-null   str
#  4   address                1252 non-null   str
#  5   open_hours             1252 non-null   str
#  6   popular_times          1252 non-null   str
#  7   website                228 non-null    str
#  8   phone                  705 non-null    str
#  9   plus_code              736 non-null    str
#  10  review_count           1252 non-null   int64
#  11  review_rating          1252 non-null   float64
#  12  reviews_per_rating     1252 non-null   str
#  13  latitude               1252 non-null   float64
#  14  longitude              1252 non-null   float64
# ...
