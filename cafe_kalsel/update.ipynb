# %%
import pandas as pd 

df = pd.read_csv('clean_data_cafekalsel.csv')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1237 entries, 0 to 1236
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_id            1237 non-null   str
#  1   link                1237 non-null   str
#  2   title               1237 non-null   str
#  3   category            1237 non-null   str
#  4   address             1237 non-null   str
#  5   open_hours          1237 non-null   str
#  6   popular_times       1237 non-null   str
#  7   review_count        1237 non-null   int64
#  8   review_rating       1237 non-null   float64
#  9   reviews_per_rating  1237 non-null   str
#  10  latitude            1237 non-null   float64
#  11  longitude           1237 non-null   float64
#  12  cid                 1237 non-null   uint64
#  13  data_id             1237 non-null   str
#  14  place_id            1237 non-null   str
#  15  images              1237 non-null   str
# ...

# %%
df_banjarmasin = df[df['address'].str.contains('Banjarmasin', case=False, na=False)]

df_banjarmasin.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 228 entries, 0 to 1236
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_id            228 non-null    str
#  1   link                228 non-null    str
#  2   title               228 non-null    str
#  3   category            228 non-null    str
#  4   address             228 non-null    str
#  5   open_hours          228 non-null    str
#  6   popular_times       228 non-null    str
#  7   review_count        228 non-null    int64
#  8   review_rating       228 non-null    float64
#  9   reviews_per_rating  228 non-null    str
#  10  latitude            228 non-null    float64
#  11  longitude           228 non-null    float64
#  12  cid                 228 non-null    uint64
#  13  data_id             228 non-null    str
#  14  place_id            228 non-null    str
#  15  images              228 non-null    str
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1237 entries, 0 to 1236
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   input_id            1237 non-null   str
#  1   link                1237 non-null   str
#  2   title               1237 non-null   str
#  3   category            1237 non-null   str
#  4   address             1237 non-null   str
#  5   open_hours          1237 non-null   str
#  6   popular_times       1237 non-null   str
#  7   review_count        1237 non-null   int64
#  8   review_rating       1237 non-null   float64
#  9   reviews_per_rating  1237 non-null   str
#  10  latitude            1237 non-null   float64
#  11  longitude           1237 non-null   float64
#  12  cid                 1237 non-null   uint64
#  13  data_id             1237 non-null   str
#  14  place_id            1237 non-null   str
#  15  images              1237 non-null   str
# ...
